# %%
#Setting csv file
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Imjuandiaz/Customer_data_Ebook/refs/heads/main/Customer%20Data%20Apr%202024%20-%20Customer%20Data.csv')

# %%
df
# Out:
#        Customer ID Title First Name Middle Name   Last Name Suffix  \
# 0            11000   NaN        Jon           V        Yang    NaN
# 1            11001   NaN     Eugene           L       Huang    NaN
# 2            11002   NaN      Ruben         NaN      Torres    NaN
# 3            11003   NaN    Christy         NaN         Zhu    NaN
# 4            11004   NaN  Elizabeth         NaN     Johnson    NaN
# ...            ...   ...        ...         ...         ...    ...
# 16514        13121   NaN    Latasha           E     Jimenez    NaN
# 16515        26100   NaN      James      Garner  Ptaszynski    NaN
# 16516        11328   NaN     Julian           M     Griffin    NaN
# 16517        23077   NaN     Marvin           A   Hernandez    NaN
# 16518        18982   NaN       Kyle         NaN       Baker    NaN
#
#            Street Address1 Street Address2             City-ZipCode-State  \
# 0          3761 N. 14th St             NaN           Cleveland-44101-Ohio
# 1               2243 W St.             NaN       Seattle-98101-Washington
# 2         5844 Linden Land             NaN           Omaha-68101-Nebraska
# 3         1825 Village Pl.             NaN         Fort Worth-76101-Texas
# 4      7553 Harness Circle             NaN       Oakland-94601-California
# ...                    ...             ...                            ...
# 16514       7259 Birchwood             NaN        San Antonio-78201-Texas
# 16515      7345 Kenwal Rd.             NaN  Pittsburgh-15201-Pennsylvania
# 16516  7398 Withersed Lane             NaN          Honolulu-96801-Hawaii
# 16517       1019 Book Road             NaN       Anaheim-92801-California
# 16518      2118 Little Dr.             NaN       Fort Wayne-46801-Indiana
#
#       Birth Date  ...      Occupation Gender Marital Status Home Owner Status  \
# 0         4/8/66  ...    Professional      M              M                 1
# 1        5/14/65  ...    Professional      M              S                 0
# 2        8/12/65  ...    Professional      M              M                 1
# 3        2/15/68  ...    Professional      F              S                 0
# 4         8/8/68  ...    Professional      F              S                 1
# ...          ...  ...             ...    ...            ...               ...
# 16514    3/22/65  ...    Professional      F              M                 1
# 16515     4/2/36  ...    Professional      F              S                 1
# 16516     1/1/40  ...      Management      M              M                 1
# 16517   10/20/46  ...  Skilled Manual      M              M                 1
# 16518     4/7/45  ...    Professional      M              S                 1
#
#        Number of Cars Owned  Number of Children At Home  \
# 0                         0                           0
# 1                         1                           3
# 2                         1                           3
# 3                         1                           0
# 4                         4                           5
# ...                     ...                         ...
# 16514                     4                           5
# 16515                     2                           0
# 16516                     2                           0
# 16517                     2                           0
# 16518                     2                           0
#
#        Total Number of Children  Annual Income  Avg Monthly Spend  \
# 0                             2         137947                 89
# 1                             3         101141                117
# 2                             3          91945                123
# 3                             0          86688                 50
# 4                             5          92771                 95
# ...                         ...            ...                ...
# 16514                         5         101542                101
# 16515                         3          46549                 46
# 16516                         5         133053                 79
# 16517                         4          31930                 65
# 16518                         4          59382                 68
#
#        eBook Subscriber Flag
# 0                          0
# 1                          1
# 2                          0
# 3                          0
# 4                          1
# ...                      ...
# 16514                      0
# 16515                      0
# 16516                      0
# 16517                      0
# 16518                      0
#
# [16519 rows x 21 columns]

# %%
#columns on the dataset
df.columns
# Out:
# Index(['Customer ID', 'Title', 'First Name', 'Middle Name', 'Last Name',
#        'Suffix', 'Street Address1', 'Street Address2', 'City-ZipCode-State',
#        'Birth Date', 'Education Level', 'Occupation', 'Gender',
#        'Marital Status', 'Home Owner Status', 'Number of Cars Owned',
#        'Number of Children At Home', 'Total Number of Children',
#        'Annual Income', 'Avg Monthly Spend', 'eBook Subscriber Flag'],
#       dtype='object')

# %%
#Creating Statistical Descriptive analisys of data

df.describe()
# Out:
#         Customer ID  Home Owner Status  Number of Cars Owned  \
# count  16519.000000       16519.000000          16519.000000
# mean   20234.225195           0.673891              1.500999
# std     5342.515987           0.468802              1.138962
# min    11000.000000           0.000000              0.000000
# 25%    15604.500000           0.000000              1.000000
# 50%    20221.000000           1.000000              2.000000
# 75%    24860.500000           1.000000              2.000000
# max    29482.000000           1.000000              4.000000
#
#        Number of Children At Home  Total Number of Children  Annual Income  \
# count                16519.000000              16519.000000   16519.000000
# mean                     0.992009                  2.006235   78122.511532
# std                      1.515048                  1.682736   39710.985718
# min                      0.000000                  0.000000    9482.000000
# 25%                      0.000000                  0.000000   47807.500000
# 50%                      0.000000                  2.000000   76120.000000
# 75%                      2.000000                  3.000000  105194.500000
# max                      5.000000                  5.000000  196511.000000
#
#        Avg Monthly Spend  eBook Subscriber Flag
# count       16519.000000           16519.000000
# mean           72.405957               0.332284
# std            27.285370               0.471046
# min            22.000000               0.000000
# 25%            52.000000               0.000000
# 50%            68.000000               0.000000
# 75%            84.000000               1.000000
# max           176.000000               1.000000

# %%
#Displaying missgno package to avoid +80% missing data
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %%
#Dropping ,'Middle Name','Street Address2','Customer ID', 'First Name', 'Last Name', 'Street Address1', because of missing +80%data
df = df.drop(['Title' ,'Suffix','Middle Name','Street Address2','Customer ID', 'First Name', 'Last Name', 'Street Address1'],axis=1)
df.shape
# Out:
# (16519, 13)

# %%
#Extractic/split Values in feature  'City-ZipCode-State
data1 = {'Customer ID': [101, 102, 103],
        'City-ZipCode-State': ['Cleveland-44101-Ohio', 'Omaha-68101-Nebraska', 'New York-10001-New York']}
df = pd.DataFrame(df)


# --- Aplica las funciones ---

# 1. Separar la columna
df[['City', 'ZipCode', 'State']] = df['City-ZipCode-State'].str.split('-', expand=True)

# 2. Eliminar la columna original (opcional)
df = df.drop(columns=['City-ZipCode-State'])


# --- Ver el resultado ---
print(df)
# Out:
#       Birth Date  Education Level      Occupation Gender Marital Status  \
# 0         4/8/66        Bachelors    Professional      M              M
# 1        5/14/65        Bachelors    Professional      M              S
# 2        8/12/65        Bachelors    Professional      M              M
# 3        2/15/68        Bachelors    Professional      F              S
# 4         8/8/68        Bachelors    Professional      F              S
# ...          ...              ...             ...    ...            ...
# 16514    3/22/65        Bachelors    Professional      F              M
# 16515     4/2/36  Partial College    Professional      F              S
# 16516     1/1/40        Bachelors      Management      M              M
# 16517   10/20/46      High School  Skilled Manual      M              M
# 16518     4/7/45      High School    Professional      M              S
#
#        Home Owner Status  Number of Cars Owned  Number of Children At Home  \
# 0                      1                     0                           0
# 1                      0                     1                           3
# 2                      1                     1                           3
# 3                      0                     1                           0
# 4                      1                     4                           5
# ...                  ...                   ...                         ...
# 16514                  1                     4                           5
# 16515                  1                     2                           0
# 16516                  1                     2                           0
# 16517                  1                     2                           0
# 16518                  1                     2                           0
#
#        Total Number of Children  Annual Income  Avg Monthly Spend  \
# 0                             2         137947                 89
# 1                             3         101141                117
# 2                             3          91945                123
# 3                             0          86688                 50
# 4                             5          92771                 95
# ...                         ...            ...                ...
# 16514                         5         101542                101
# 16515                         3          46549                 46
# 16516                         5         133053                 79
# 16517                         4          31930                 65
# 16518                         4          59382                 68
#
#        eBook Subscriber Flag         City ZipCode         State
# 0                          0    Cleveland   44101          Ohio
# 1                          1      Seattle   98101    Washington
# 2                          0        Omaha   68101      Nebraska
# 3                          0   Fort Worth   76101         Texas
# 4                          1      Oakland   94601    California
# ...                      ...          ...     ...           ...
# 16514                      0  San Antonio   78201         Texas
# 16515                      0   Pittsburgh   15201  Pennsylvania
# 16516                      0     Honolulu   96801        Hawaii
# 16517                      0      Anaheim   92801    California
# 16518                      0   Fort Wayne   46801       Indiana
#
# [16519 rows x 15 columns]

# %%
# Import necessary libraries
from datetime import datetime
import pandas as pd

# 1. Define the function to calculate age, corrected for negative ages
def calculate_age(born):
    today = datetime.today()
    age = today.year - born.year - ((today.month, today.day) < (born.month, born.day))
    if age < 0:  # Correct negative ages caused by 1900s vs 2000s
        age += 100
    return age

# 2. Convert your 'Birth Date' column to datetime format.
df['birth_date_dt'] = pd.to_datetime(df['Birth Date'], format='%m/%d/%y', errors='coerce')

# 3. Drop rows with invalid dates
df.dropna(subset=['birth_date_dt'], inplace=True)

# 4. Create the new 'Age' column by applying the function
df['Age'] = df['birth_date_dt'].apply(calculate_age)

# 5. Convert the age to integer
df['Age'] = df['Age'].astype(int)

# 6. Drop the intermediate datetime column
df.drop(columns=['birth_date_dt'], inplace=True)

# Optional: Check result
print(df[['Birth Date', 'Age']].head())
# Out:
#   Birth Date  Age
# 0     4/8/66   59
# 1    5/14/65   60
# 2    8/12/65   60
# 3    2/15/68   57
# 4     8/8/68   57

# %%
#drop column 'Birth Date' instead of AGE
df = df.drop(columns=['Birth Date'])


df
# Out:
#        Education Level      Occupation Gender Marital Status  \
# 0            Bachelors    Professional      M              M
# 1            Bachelors    Professional      M              S
# 2            Bachelors    Professional      M              M
# 3            Bachelors    Professional      F              S
# 4            Bachelors    Professional      F              S
# ...                ...             ...    ...            ...
# 16514        Bachelors    Professional      F              M
# 16515  Partial College    Professional      F              S
# 16516        Bachelors      Management      M              M
# 16517      High School  Skilled Manual      M              M
# 16518      High School    Professional      M              S
#
#        Home Owner Status  Number of Cars Owned  Number of Children At Home  \
# 0                      1                     0                           0
# 1                      0                     1                           3
# 2                      1                     1                           3
# 3                      0                     1                           0
# 4                      1                     4                           5
# ...                  ...                   ...                         ...
# 16514                  1                     4                           5
# 16515                  1                     2                           0
# 16516                  1                     2                           0
# 16517                  1                     2                           0
# 16518                  1                     2                           0
#
#        Total Number of Children  Annual Income  Avg Monthly Spend  \
# 0                             2         137947                 89
# 1                             3         101141                117
# 2                             3          91945                123
# 3                             0          86688                 50
# 4                             5          92771                 95
# ...                         ...            ...                ...
# 16514                         5         101542                101
# 16515                         3          46549                 46
# 16516                         5         133053                 79
# 16517                         4          31930                 65
# 16518                         4          59382                 68
#
#        eBook Subscriber Flag         City ZipCode         State  Age
# 0                          0    Cleveland   44101          Ohio   59
# 1                          1      Seattle   98101    Washington   60
# 2                          0        Omaha   68101      Nebraska   60
# 3                          0   Fort Worth   76101         Texas   57
# 4                          1      Oakland   94601    California   57
# ...                      ...          ...     ...           ...  ...
# 16514                      0  San Antonio   78201         Texas   60
# 16515                      0   Pittsburgh   15201  Pennsylvania   89
# 16516                      0     Honolulu   96801        Hawaii   85
# 16517                      0      Anaheim   92801    California   78
# 16518                      0   Fort Wayne   46801       Indiana   80
#
# [16519 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Education Level', 'Occupation', 'Gender', 'Marital Status',
#        'Home Owner Status', 'Number of Cars Owned',
#        'Number of Children At Home', 'Total Number of Children',
#        'Annual Income', 'Avg Monthly Spend', 'eBook Subscriber Flag', 'City',
#        'ZipCode', 'State', 'Age'],
#       dtype='object')

# %%
# Installing ydata profiling package for detailed data profiling (Exploratory Data Analysis, EDA)
# !pip install -U ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.11/dist-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /usr/local/lib/python3.11/dist-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.0.2)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
#installing ydata profiling package for deatailed data profiling
from ydata_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_file(output_file='customer_Data_Ebook_2025.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#  20%|██        | 3/15 [00:00<00:00, 21.60it/s]
# 100%|██████████| 15/15 [00:00<00:00, 38.58it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#installing significant correlated test package dython
# !pip install dython
# Out:
# Collecting dython
#   Downloading dython-0.7.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from dython) (2.0.2)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from dython) (2.2.2)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from dython) (0.13.2)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from dython) (1.15.3)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from dython) (3.10.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from dython) (1.6.1)
# Requirement already satisfied: psutil>=5.9.1 in /usr/local/lib/python3.11/dist-packages (from dython) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dython) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->dython) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.2->dython) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.2->dython) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24.2->dython) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24.2->dython) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->dython) (1.17.0)
# Downloading dython-0.7.9-py3-none-any.whl (26 kB)
# Installing collected packages: dython
# Successfully installed dython-0.7.9

# %%
#setting correlations test on the 'Avg Monthly Spend' and 'eBook Subscriber Flag'
import dython
from dython.nominal import associations

#running assoc funtion
assoc = associations(df)

# %%
# Storing the correlations in a matrix
assoc_matrix = assoc['corr']

# %%
# Setting the target variable eBook Subscriber Flag
target = 'eBook Subscriber Flag'


# List the associated variables in the descending order of influence on the target variable
assoc_matrix[target].abs().sort_values(ascending=False)
# Out:
# eBook Subscriber Flag         1.000000
# Number of Children At Home    0.456377
# Avg Monthly Spend             0.421783
# Annual Income                 0.287080
# Total Number of Children      0.233467
# Marital Status                0.192870
# Occupation                    0.181197
# Number of Cars Owned          0.164751
# Age                           0.124583
# Gender                        0.120068
# Education Level               0.100951
# ZipCode                       0.063050
# City                          0.063050
# State                         0.042419
# Home Owner Status             0.000552
# Name: eBook Subscriber Flag, dtype: float64

# %%
# Setting the target variable Avg Monthly Spend
target = 'Avg Monthly Spend'


# List the associated variables in the descending order of influence on the target variable
assoc_matrix[target].abs().sort_values(ascending=False)
# Out:
# Avg Monthly Spend             1.000000
# Number of Children At Home    0.730421
# Annual Income                 0.607616
# Gender                        0.571759
# Total Number of Children      0.500159
# eBook Subscriber Flag         0.421783
# Occupation                    0.381327
# Number of Cars Owned          0.346670
# Marital Status                0.218891
# Home Owner Status             0.134242
# Education Level               0.112400
# City                          0.062259
# ZipCode                       0.062259
# State                         0.040120
# Age                           0.037798
# Name: Avg Monthly Spend, dtype: float64

# %%
# Installing AutoViz package for auto visualizations
# !pip install autoviz

# Importing Autoviz modules
from autoviz.AutoViz_Class import AutoViz_Class


# Starting the Autoviz instance
AV = AutoViz_Class()




# Generating visuals using AutoViz modules
AV.AutoViz(df, verbose = 2, depVar= 'Avg Monthly Spend')
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.11/dist-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.9.4)
# Collecting emoji (from autoviz)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from autoviz)
#   Downloading pyamg-5.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from autoviz) (0.14.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (from autoviz) (0.19.0)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from autoviz) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from autoviz) (4.14.1)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Downloading pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (2.0.2)
# Collecting hvplot>=0.9.2 (from autoviz)
#   Downloading hvplot-0.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: holoviews>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.21.0)
# Requirement already satisfied: panel>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.7.5)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in /usr/local/lib/python3.11/dist-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in /usr/local/lib/python3.11/dist-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (3.7.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (25.0)
# Requirement already satisfied: param<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (2.2.1)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (3.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (3.8.2)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->autoviz) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->autoviz) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->autoviz) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->autoviz) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->autoviz) (1.0.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.1.1)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2025.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.11/dist-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Downloading autoviz-0.1.905-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 1.5 MB/s eta 0:00:00
# Downloading hvplot-0.12.0-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 3.5 MB/s eta 0:00:00
# Downloading pandas_dq-1.29-py3-none-any.whl (29 kB)
# Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 5.8 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 42.3 MB/s eta 0:00:00
# Downloading pyamg-5.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 80.5 MB/s eta 0:00:00
# Installing collected packages: emoji, xgboost, pyamg, pandas-dq, hvplot, autoviz
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.0.4
#     Uninstalling xgboost-3.0.4:
#       Successfully uninstalled xgboost-3.0.4
# Successfully installed autoviz-0.1.905 emoji-2.14.1 hvplot-0.12.0 pandas-dq-1.29 pyamg-5.2.1 xgboost-1.6.2
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (16519, 15)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : []
#     Integer-Categorical Columns: ['Number of Cars Owned', 'Number of Children At Home', 'Total Number of Children', 'Annual Income', 'Age']
#     String-Categorical Columns: ['Education Level', 'Occupation', 'State', 'City', 'ZipCode']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['Gender', 'Marital Status']
#     Numeric-Boolean Columns: ['Home Owner Status', 'eBook Subscriber Flag']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     14 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Regression problem #####################
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['Gender', 'Marital Status', 'Home Owner Status', 'eBook Subscriber Flag']"
#    Categorical variables %s
# ("   ['Education Level', 'Occupation', 'State', 'City', 'ZipCode', 'Gender', "
#  "'Marital Status', 'Home Owner Status', 'eBook Subscriber Flag']")
#    Continuous variables %s
# ("   ['Number of Cars Owned', 'Number of Children At Home', 'Total Number of "
#  "Children', 'Annual Income', 'Age']")
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   Avg Monthly Spend'
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_0f342_row0_col0, #T_0f342_row0_col3, #T_0f342_row0_col4, #T_0f342_row0_col5, #T_0f342_row1_col0, #T_0f342_row1_col3, #T_0f342_row1_col4, #T_0f342_row1_col5, #T_0f342_row2_col0, #T_0f342_row2_col3, #T_0f342_row2_col4, #T_0f342_row2_col5, #T_0f342_row3_col0, #T_0f342_row3_col3, #T_0f342_row3_col4, #T_0f342_row3_col5, #T_0f342_row4_col0, #T_0f342_row4_col3, #T_0f342_row4_col4, #T_0f342_row4_col5, #T_0f342_row5_col0, #T_0f342_row5_col3, #T_0f342_row5_col4, #T_0f342_row5_col5, #T_0f342_row6_col0, #T_0f342_row6_col3, #T_0f342_row6_col4, #T_0f342_row6_col5, #T_0f342_row7_col0, #T_0f342_row7_col3, #T_0f342_row7_col4, #T_0f342_row7_col5, #T_0f342_row8_col0, #T_0f342_row8_col3, #T_0f342_row8_col4, #T_0f342_row8_col5, #T_0f342_row9_col0, #T_0f342_row9_col3, #T_0f342_row9_col4, #T_0f342_row9_col5, #T_0f342_row10_col0, #T_0f342_row10_col3, #T_0f342_row10_col4, #T_0f342_row10_col5, #T_0f342_row11_col0, #T_0f342_row11_col3, #T_0f342_row11_col4, #T_0f342_row11_col5, #T_0f342_row12_col0, #T_0f342_row12_col3, #T_0f342_row12_col4, #T_0f342_row12_col5, #T_0f342_row13_col0, #T_0f342_row13_col3, #T_0f342_row13_col4, #T_0f342_row13_col5, #T_0f342_row14_col0, #T_0f342_row14_col3, #T_0f342_row14_col4, #T_0f342_row14_col5 {
#   font-family: Segoe UI;
# }
# #T_0f342_row0_col1, #T_0f342_row0_col2, #T_0f342_row1_col1, #T_0f342_row1_col2, #T_0f342_row2_col1, #T_0f342_row2_col2, #T_0f342_row3_col1, #T_0f342_row3_col2, #T_0f342_row4_col1, #T_0f342_row4_col2, #T_0f342_row5_col1, #T_0f342_row5_col2, #T_0f342_row6_col1, #T_0f342_row6_col2, #T_0f342_row7_col1, #T_0f342_row7_col2, #T_0f342_row8_col1, #T_0f342_row9_col1, #T_0f342_row9_col2, #T_0f342_row10_col1, #T_0f342_row10_col2, #T_0f342_row11_col1, #T_0f342_row11_col2, #T_0f342_row12_col1, #T_0f342_row12_col2, #T_0f342_row13_col1, #T_0f342_row13_col2, #T_0f342_row14_col1, #T_0f342_row14_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0f342_row8_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_0f342" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f342_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_0f342_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_0f342_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_0f342_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_0f342_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_0f342_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f342_level0_row0" class="row_heading level0 row0" >Education Level</th>
#       <td id="T_0f342_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_0f342_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_0f342_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0f342_row0_col3" class="data row0 col3" ></td>
#       <td id="T_0f342_row0_col4" class="data row0 col4" ></td>
#       <td id="T_0f342_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row1" class="row_heading level0 row1" >Occupation</th>
#       <td id="T_0f342_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_0f342_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0f342_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0f342_row1_col3" class="data row1 col3" ></td>
#       <td id="T_0f342_row1_col4" class="data row1 col4" ></td>
#       <td id="T_0f342_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row2" class="row_heading level0 row2" >Gender</th>
#       <td id="T_0f342_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_0f342_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_0f342_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_0f342_row2_col3" class="data row2 col3" ></td>
#       <td id="T_0f342_row2_col4" class="data row2 col4" ></td>
#       <td id="T_0f342_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row3" class="row_heading level0 row3" >Marital Status</th>
#       <td id="T_0f342_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_0f342_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_0f342_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0f342_row3_col3" class="data row3 col3" ></td>
#       <td id="T_0f342_row3_col4" class="data row3 col4" ></td>
#       <td id="T_0f342_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row4" class="row_heading level0 row4" >Home Owner Status</th>
#       <td id="T_0f342_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_0f342_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_0f342_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_0f342_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_0f342_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0f342_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row5" class="row_heading level0 row5" >Number of Cars Owned</th>
#       <td id="T_0f342_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_0f342_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_0f342_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_0f342_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_0f342_row5_col4" class="data row5 col4" >4.000000</td>
#       <td id="T_0f342_row5_col5" class="data row5 col5" >Column has 1137 outliers greater than upper bound (3.50) or lower than lower bound(-0.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row6" class="row_heading level0 row6" >Number of Children At Home</th>
#       <td id="T_0f342_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_0f342_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_0f342_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_0f342_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_0f342_row6_col4" class="data row6 col4" >5.000000</td>
#       <td id="T_0f342_row6_col5" class="data row6 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row7" class="row_heading level0 row7" >Total Number of Children</th>
#       <td id="T_0f342_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_0f342_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_0f342_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_0f342_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_0f342_row7_col4" class="data row7 col4" >5.000000</td>
#       <td id="T_0f342_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row8" class="row_heading level0 row8" >Annual Income</th>
#       <td id="T_0f342_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_0f342_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_0f342_row8_col2" class="data row8 col2" >93</td>
#       <td id="T_0f342_row8_col3" class="data row8 col3" >9482.000000</td>
#       <td id="T_0f342_row8_col4" class="data row8 col4" >196511.000000</td>
#       <td id="T_0f342_row8_col5" class="data row8 col5" >Column has 7 outliers greater than upper bound (191275.00) or lower than lower bound(-38273.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0f342_level0_row9" class="row_heading level0 row9" >eBook Subscriber Flag</th>
#       <td id="T_0f342_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_0f342_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_0f342_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_0f342_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_0f342_row9_col4" clas
# Number of All Scatter Plots = 15
# All Plots are saved in ./AutoViz_Plots/Avg Monthly Spend
# Time to run AutoViz = 13 seconds
#       Education Level     Occupation   Gender Marital Status  \
# 0            Bachelors    Professional    M          M
# 1            Bachelors    Professional    M          S
# 2            Bachelors    Professional    M          M
# 3            Bachelors    Professional    F          S
# 4            Bachelors    Professional    F          S
# ...                ...             ...    ...            ...
# 16514        Bachelors    Professional    F          M
# 16515  Partial College    Professional    F          S
# 16516        Bachelors      Management    M          M
# 16517      High School  Skilled Manual    M          M
# 16518      High School    Professional    M          S
#
#        Home Owner Status  Number of Cars Owned  Number of Children At Home  \
# 0              1                    0                        0
# 1              0                    1                        3
# 2              1                    1                        3
# 3              0                    1                        0
# 4              1                    4                        5
# ...                  ...                   ...                         ...
# 16514          1                    4                        5
# 16515          1                    2                        0
# 16516          1                    2                        0
# 16517          1                    2                        0
# 16518          1                    2                        0
#
#        Total Number of Children  Annual Income  eBook Subscriber Flag  \
# 0                  2                137947                0
# 1                  3                101141                1
# 2                  3                 91945                0
# 3                  0                 86688                0
# 4                  5                 92771                1
# ...                         ...            ...                    ...
# 16514              5                101542                0
# 16515              3                 46549                0
# 16516              5                133053                0
# 16517              4                 31930                0
# 16518              4                 59382                0
#
#           City     ZipCode     State      Age  Avg Monthly Spend
# 0        Cleveland   44101          Ohio  59           89
# 1          Seattle   98101    Washington  60          117
# 2            Omaha   68101      Nebraska  60          123
# 3       Fort Worth   76101         Texas  57           50
# 4          Oakland   94601    California  57           95
# ...            ...     ...           ...  ...                ...
# 16514  San Antonio   78201         Texas  60          101
# 16515   Pittsburgh   15201  Pennsylvania  89           46
# 16516     Honolulu   96801        Hawaii  85           79
# 16517      Anaheim   92801    California  78           65
# 16518   Fort Wayne   46801       Indiana  80           68
#
# [16519 rows x 15 columns]

# %%
# Starting the Autoviz instance
AV = AutoViz_Class()




# Generating visuals using AutoViz modules
AV.AutoViz(df, verbose = 2, depVar= 'eBook Subscriber Flag')
# Out:
# Shape of your Data Set loaded: (16519, 15)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : []
#     Integer-Categorical Columns: ['Number of Cars Owned', 'Number of Children At Home', 'Total Number of Children', 'Annual Income', 'Avg Monthly Spend', 'Age']
#     String-Categorical Columns: ['Education Level', 'Occupation', 'State', 'City', 'ZipCode']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['Gender', 'Marital Status']
#     Numeric-Boolean Columns: ['Home Owner Status']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     14 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Binary_Classification problem #####################
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['Gender', 'Marital Status', 'Home Owner Status']"
#    Categorical variables %s
# ("   ['Education Level', 'Occupation', 'State', 'City', 'ZipCode', 'Gender', "
#  "'Marital Status', 'Home Owner Status']")
#    Continuous variables %s
# ("   ['Number of Cars Owned', 'Number of Children At Home', 'Total Number of "
#  "Children', 'Annual Income', 'Avg Monthly Spend', 'Age']")
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   eBook Subscriber Flag'
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_1f8a8_row0_col0, #T_1f8a8_row0_col3, #T_1f8a8_row0_col4, #T_1f8a8_row0_col5, #T_1f8a8_row1_col0, #T_1f8a8_row1_col3, #T_1f8a8_row1_col4, #T_1f8a8_row1_col5, #T_1f8a8_row2_col0, #T_1f8a8_row2_col3, #T_1f8a8_row2_col4, #T_1f8a8_row2_col5, #T_1f8a8_row3_col0, #T_1f8a8_row3_col3, #T_1f8a8_row3_col4, #T_1f8a8_row3_col5, #T_1f8a8_row4_col0, #T_1f8a8_row4_col3, #T_1f8a8_row4_col4, #T_1f8a8_row4_col5, #T_1f8a8_row5_col0, #T_1f8a8_row5_col3, #T_1f8a8_row5_col4, #T_1f8a8_row5_col5, #T_1f8a8_row6_col0, #T_1f8a8_row6_col3, #T_1f8a8_row6_col4, #T_1f8a8_row6_col5, #T_1f8a8_row7_col0, #T_1f8a8_row7_col3, #T_1f8a8_row7_col4, #T_1f8a8_row7_col5, #T_1f8a8_row8_col0, #T_1f8a8_row8_col3, #T_1f8a8_row8_col4, #T_1f8a8_row8_col5, #T_1f8a8_row9_col0, #T_1f8a8_row9_col3, #T_1f8a8_row9_col4, #T_1f8a8_row9_col5, #T_1f8a8_row10_col0, #T_1f8a8_row10_col3, #T_1f8a8_row10_col4, #T_1f8a8_row10_col5, #T_1f8a8_row11_col0, #T_1f8a8_row11_col3, #T_1f8a8_row11_col4, #T_1f8a8_row11_col5, #T_1f8a8_row12_col0, #T_1f8a8_row12_col3, #T_1f8a8_row12_col4, #T_1f8a8_row12_col5, #T_1f8a8_row13_col0, #T_1f8a8_row13_col3, #T_1f8a8_row13_col4, #T_1f8a8_row13_col5, #T_1f8a8_row14_col0, #T_1f8a8_row14_col3, #T_1f8a8_row14_col4, #T_1f8a8_row14_col5 {
#   font-family: Segoe UI;
# }
# #T_1f8a8_row0_col1, #T_1f8a8_row0_col2, #T_1f8a8_row1_col1, #T_1f8a8_row1_col2, #T_1f8a8_row2_col1, #T_1f8a8_row2_col2, #T_1f8a8_row3_col1, #T_1f8a8_row3_col2, #T_1f8a8_row4_col1, #T_1f8a8_row4_col2, #T_1f8a8_row5_col1, #T_1f8a8_row5_col2, #T_1f8a8_row6_col1, #T_1f8a8_row6_col2, #T_1f8a8_row7_col1, #T_1f8a8_row7_col2, #T_1f8a8_row8_col1, #T_1f8a8_row9_col1, #T_1f8a8_row9_col2, #T_1f8a8_row10_col1, #T_1f8a8_row10_col2, #T_1f8a8_row11_col1, #T_1f8a8_row11_col2, #T_1f8a8_row12_col1, #T_1f8a8_row12_col2, #T_1f8a8_row13_col1, #T_1f8a8_row13_col2, #T_1f8a8_row14_col1, #T_1f8a8_row14_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_1f8a8_row8_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_1f8a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f8a8_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_1f8a8_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_1f8a8_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_1f8a8_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_1f8a8_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_1f8a8_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f8a8_level0_row0" class="row_heading level0 row0" >Education Level</th>
#       <td id="T_1f8a8_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_1f8a8_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_1f8a8_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1f8a8_row0_col3" class="data row0 col3" ></td>
#       <td id="T_1f8a8_row0_col4" class="data row0 col4" ></td>
#       <td id="T_1f8a8_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row1" class="row_heading level0 row1" >Occupation</th>
#       <td id="T_1f8a8_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_1f8a8_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_1f8a8_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_1f8a8_row1_col3" class="data row1 col3" ></td>
#       <td id="T_1f8a8_row1_col4" class="data row1 col4" ></td>
#       <td id="T_1f8a8_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row2" class="row_heading level0 row2" >Gender</th>
#       <td id="T_1f8a8_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_1f8a8_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_1f8a8_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_1f8a8_row2_col3" class="data row2 col3" ></td>
#       <td id="T_1f8a8_row2_col4" class="data row2 col4" ></td>
#       <td id="T_1f8a8_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row3" class="row_heading level0 row3" >Marital Status</th>
#       <td id="T_1f8a8_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_1f8a8_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_1f8a8_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_1f8a8_row3_col3" class="data row3 col3" ></td>
#       <td id="T_1f8a8_row3_col4" class="data row3 col4" ></td>
#       <td id="T_1f8a8_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row4" class="row_heading level0 row4" >Home Owner Status</th>
#       <td id="T_1f8a8_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_1f8a8_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_1f8a8_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_1f8a8_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_1f8a8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_1f8a8_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row5" class="row_heading level0 row5" >Number of Cars Owned</th>
#       <td id="T_1f8a8_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_1f8a8_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_1f8a8_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_1f8a8_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_1f8a8_row5_col4" class="data row5 col4" >4.000000</td>
#       <td id="T_1f8a8_row5_col5" class="data row5 col5" >Column has 1137 outliers greater than upper bound (3.50) or lower than lower bound(-0.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row6" class="row_heading level0 row6" >Number of Children At Home</th>
#       <td id="T_1f8a8_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_1f8a8_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_1f8a8_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_1f8a8_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_1f8a8_row6_col4" class="data row6 col4" >5.000000</td>
#       <td id="T_1f8a8_row6_col5" class="data row6 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row7" class="row_heading level0 row7" >Total Number of Children</th>
#       <td id="T_1f8a8_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_1f8a8_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_1f8a8_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_1f8a8_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_1f8a8_row7_col4" class="data row7 col4" >5.000000</td>
#       <td id="T_1f8a8_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row8" class="row_heading level0 row8" >Annual Income</th>
#       <td id="T_1f8a8_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_1f8a8_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_1f8a8_row8_col2" class="data row8 col2" >93</td>
#       <td id="T_1f8a8_row8_col3" class="data row8 col3" >9482.000000</td>
#       <td id="T_1f8a8_row8_col4" class="data row8 col4" >196511.000000</td>
#       <td id="T_1f8a8_row8_col5" class="data row8 col5" >Column has 7 outliers greater than upper bound (191275.00) or lower than lower bound(-38273.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a8_level0_row9" class="row_heading level0 row9" >Avg Monthly Spend</th>
#       <td id="T_1f8a8_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_1f8a8_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_1f8a8_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_1f8a8_row9_col3" class="data row9 col3" >22.000000</td>
#       <td id="T_1f8a8_row9_col4" class="
# Total Number of Scatter Plots = 21
# All Plots are saved in ./AutoViz_Plots/eBook Subscriber Flag
# Time to run AutoViz = 18 seconds
#       Education Level     Occupation   Gender Marital Status  \
# 0            Bachelors    Professional    M          M
# 1            Bachelors    Professional    M          S
# 2            Bachelors    Professional    M          M
# 3            Bachelors    Professional    F          S
# 4            Bachelors    Professional    F          S
# ...                ...             ...    ...            ...
# 16514        Bachelors    Professional    F          M
# 16515  Partial College    Professional    F          S
# 16516        Bachelors      Management    M          M
# 16517      High School  Skilled Manual    M          M
# 16518      High School    Professional    M          S
#
#        Home Owner Status  Number of Cars Owned  Number of Children At Home  \
# 0              1                    0                        0
# 1              0                    1                        3
# 2              1                    1                        3
# 3              0                    1                        0
# 4              1                    4                        5
# ...                  ...                   ...                         ...
# 16514          1                    4                        5
# 16515          1                    2                        0
# 16516          1                    2                        0
# 16517          1                    2                        0
# 16518          1                    2                        0
#
#        Total Number of Children  Annual Income  Avg Monthly Spend  \
# 0                  2                137947              89
# 1                  3                101141             117
# 2                  3                 91945             123
# 3                  0                 86688              50
# 4                  5                 92771              95
# ...                         ...            ...                ...
# 16514              5                101542             101
# 16515              3                 46549              46
# 16516              5                133053              79
# 16517              4                 31930              65
# 16518              4                 59382              68
#
#           City     ZipCode     State      Age  eBook Subscriber Flag
# 0        Cleveland   44101          Ohio  59             0
# 1          Seattle   98101    Washington  60             1
# 2            Omaha   68101      Nebraska  60             0
# 3       Fort Worth   76101         Texas  57             0
# 4          Oakland   94601    California  57             1
# ...            ...     ...           ...  ...                    ...
# 16514  San Antonio   78201         Texas  60             0
# 16515   Pittsburgh   15201  Pennsylvania  89             0
# 16516     Honolulu   96801        Hawaii  85             0
# 16517      Anaheim   92801    California  78             0
# 16518   Fort Wayne   46801       Indiana  80             0
#
# [16519 rows x 15 columns]
